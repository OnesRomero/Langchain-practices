# %%
from dotenv import load_dotenv

load_dotenv()

# %% [markdown]
# ## Inicializar e invocar el modelo

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("¿Cuál es la capital de la Luna?")
 
response

# %%
print(response.content)

# %%
from pprint import pprint

pprint(response.response_metadata)

# %% [markdown]
# ## Personalizar el modelo

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Argumentos pasados al modelo:
    temperature=1.0
)

response = model.invoke("¿Cuál es la capital de la Luna?")
print(response.content)

# %% [markdown]
# ## Proveedores de modelos

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(
    model="google/gemma-4-12b",
    model_provider="openai",
    base_url="http://localhost:1234/v1",
    temperature=1.0,
    api_key="lm-studio"
)

response = model.invoke("¿Cuál es la capital de la Luna?")

print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

response = model.invoke("¿Cuál es la capital de la Luna?")

print(response.content)

# %% [markdown]
# ## Inicializar e invocar un Agente

# %%
from langchain.agents import create_agent

model = init_chat_model(model="gpt-5-nano")

agent = create_agent(model=model)

# %%
# agent = create_agent(model="claude-sonnet-4-6")

# %%
# agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="¿Cuál es la capital de la Luna?")]}
)

# %%
from pprint import pprint

pprint(response)

# %%
print(response['messages'][-1].content)

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="¿Cuál es la capital de la Luna?"),
    AIMessage(content="La capital de la Luna es Luna City."),
    HumanMessage(content="Interesante, cuéntame más sobre Luna City.")]}
)

pprint(response)

# %% [markdown]
# ## Salida en modo Stream

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Cuéntame todo sobre Luna City, la capital de la Luna.")]},
    stream_mode="messages"
):

# El token es un fragmento de mensaje con el contenido del token.
# Los metadatos contienen información sobre qué nodo generó el token.
    
    if token.content:  # Comprueba si hay contenido real.
        print(token.content, end="", flush=True)  # Imprimir token
